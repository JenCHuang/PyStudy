# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=r'C:\Users\Student\My_iSpan\ziSpanProject_data\origin\installments_payments.csv'
dataf = pd.read_csv(data)
dataf
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
dataf.isnull().sum()
# Out:
# SK_ID_PREV                   0
# SK_ID_CURR                   0
# NUM_INSTALMENT_VERSION       0
# NUM_INSTALMENT_NUMBER        0
# DAYS_INSTALMENT              0
# DAYS_ENTRY_PAYMENT        2905
# AMT_INSTALMENT               0
# AMT_PAYMENT               2905
# dtype: int64

# %%
test_sec = dataf['DAYS_ENTRY_PAYMENT'] - dataf['DAYS_INSTALMENT']
dataf['entry_late'] = (test_sec>0)*test_sec
dataf
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
col = 'entry_late'
print(np.max(dataf[col]))
print(sum(dataf[col]>0))
dataf[col].hist()
# Out:
# 2884.0
# 1146669
# <AxesSubplot:>

# %%
test_sec = dataf['AMT_INSTALMENT'] - dataf['AMT_PAYMENT']
dataf['PAYMENT_nonpay'] = (test_sec>0)*test_sec
dataf
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
col = 'PAYMENT_nonpay'
print(np.max(dataf[col]))
print(sum(dataf[col]>0))
dataf[col].hist()
# Out:
# 2424726.4050000003
# 1295493
# <AxesSubplot:>

# %%
dataf = dataf.fillna(0)
dataf['late_count']= ((dataf['entry_late']+dataf['PAYMENT_nonpay'])>0)*1
dataf
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
print(sum(dataf['late_count']))
# Out:
# 1789187

# %%
dataf = dataf.groupby('SK_ID_PREV',as_index = False).aggregate({
    'SK_ID_CURR':'max',
    'NUM_INSTALMENT_NUMBER':'count',
    'late_count':'sum'
})
dataf
# Out:
#         SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_NUMBER  late_count
# 0          1000001      158271                      2           0
# 1          1000002      101962                      4           0
# 2          1000003      252457                      3           0
# 3          1000004      260094                      7           0
# 4          1000005      176456                     11           3
# ...            ...         ...                    ...         ...
# 997747     2843495      260963                      7           1
# 997748     2843496      425374                     34           4
# 997749     2843497      451578                     20           0
# 997750     2843498      393881                      6           0
# 997751     2843499      314148                     10           0
#
# [997752 rows x 4 columns]

# %%
dataf.columns = ['SK_ID_PREV','SK_ID_CURR','INSTALMENT_count','late_count_total']
dataf['late_label'] = (dataf['late_count_total']>0)*1
dataf
# Out:
#         SK_ID_PREV  SK_ID_CURR  INSTALMENT_count  late_count_total  late_label
# 0          1000001      158271                 2                 0           0
# 1          1000002      101962                 4                 0           0
# 2          1000003      252457                 3                 0           0
# 3          1000004      260094                 7                 0           0
# 4          1000005      176456                11                 3           1
# ...            ...         ...               ...               ...         ...
# 997747     2843495      260963                 7                 1           1
# 997748     2843496      425374                34                 4           1
# 997749     2843497      451578                20                 0           0
# 997750     2843498      393881                 6                 0           0
# 997751     2843499      314148                10                 0           0
#
# ...

# %%
dataf = dataf.groupby('SK_ID_CURR',as_index = False).aggregate({
    'SK_ID_PREV':'count',
    'INSTALMENT_count':'sum',
    'late_count_total':'sum',
    'late_label':'sum'
})
dataf
# Out:
#         SK_ID_CURR  SK_ID_PREV  INSTALMENT_count  late_count_total  late_label
# 0           100001           2                 7                 1           1
# 1           100002           1                19                 0           0
# 2           100003           3                25                 0           0
# 3           100004           1                 3                 0           0
# 4           100005           1                 9                 1           1
# ...            ...         ...               ...               ...         ...
# 339582      456251           1                 7                 0           0
# 339583      456252           1                 6                 1           1
# 339584      456253           3                14                 2           1
# 339585      456254           2                19                 0           0
# 339586      456255           6                74                21           5
#
# ...

# %%
dataf.columns = ['SK_ID_CURR','Loan_count','INSTALMENT_count','late_count_total','late_count_inLoan']
dataf
# Out:
#         SK_ID_CURR  Loan_count  INSTALMENT_count  late_count_total  \
# 0           100001           2                 7                 1
# 1           100002           1                19                 0
# 2           100003           3                25                 0
# 3           100004           1                 3                 0
# 4           100005           1                 9                 1
# ...            ...         ...               ...               ...
# 339582      456251           1                 7                 0
# 339583      456252           1                 6                 1
# 339584      456253           3                14                 2
# 339585      456254           2                19                 0
# 339586      456255           6                74                21
#
#         late_count_inLoan
# 0                       1
# 1                       0
# 2                       0
# 3                       0
# ...

# %%
data=r'C:\Users\Student\My_iSpan\ziSpanProject_data\processed\processed_installments_payments.csv'
dataf.to_csv(data,index = False)

# %%
sum(dataf['late_count_inLoan']>0)
# Out:
# 183537

# %%
dataf['late_count_inLoan'].hist()
# Out:
# <AxesSubplot:>

# %%
dataf['late_count_total'].hist()
# Out:
# <AxesSubplot:>
